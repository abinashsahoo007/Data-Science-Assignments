# %% [markdown]
# # Assignment 2

# %% [markdown]
# # Basics Statistics Level-2

# %% [markdown]
# # SET-1

# %% [markdown]
# # Qno-1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
x=pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])

# %%
names=['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co','Lehman Brothers','Marriott',
      'MCI','Merrill Lynch','Microsoft','Morgan Stanley','Sun Microsystems','Travelers','US Airways','Warner-Lambert']

# %%
#pie plot
plt.figure(figsize=(7,7))
plt.pie(x,labels=names,autopct='%.2f')
plt.show()

# %%
#boxplot
sns.boxplot(x)
# Out:
# <Axes: >

# %%
print('Mean =',x.mean())
print('Variance =',x.var())
print('Standard Deviation =',x.std())
# Out:
# Mean = 33.27133333333333
# Variance = 287.1466123809524
# Standard Deviation = 16.945400921222028

# %% [markdown]
# # SET-2

# %% [markdown]
# # Qno-1

# %%
#the service will began 10 after car dropoff 45+10
#so new mean is 55
#probability it will take 1 hours to complete

p1=1-stats.norm.cdf(60,55,8)
p1
# Out:
# 0.26598552904870054

# %% [markdown]
# # Qno-2

# %% [markdown]
# # Qno-2(a)

# %%
mean=38
std=6
#probability less than 44
p1=1-stats.norm.cdf(44,38,6)
print('probability more than 44',p1)
#probability less than 38
p_b=1-stats.norm.cdf(38,38,6)
p2=p_b-p1
print('probability between 38 and 44',p2)
true_or_false=(p1 > p2)
print('Answer:',true_or_false)
# Out:
# probability more than 44 0.15865525393145707
# probability between 38 and 44 0.3413447460685429
# Answer: False

# %% [markdown]
# # Qno-2(b)

# %%
p=stats.norm.cdf(30,38,6)
print('training program for employees under the age of 30 at the center about', 400*p)
# Out:
# training program for employees under the age of 30 at the center about 36.484487890347154

# %% [markdown]
# # Qno-4

# %%
mean=100
std=20
#random value taken between them is 0.99
stats.norm.interval(0.99,100,20)
# Out:
# (48.48341392902199, 151.516586070978)

# %% [markdown]
# # Qno-5

# %% [markdown]
# # Qno-5(a)

# %%
#X1~N(5,3)
#X2~N(7,4)
#X1+X2
#X~N(12,7)  --->It is in millions. Convert it into rupees
#Convert it into rupees , 1million=45rupees  , So X*45
#X~N(540,225)  converted into rupees

# %%
#mean=540
#std=225
#Specify a Rupee range such that it contains 95% probability for the annual profit of the company
p1=stats.norm.interval(0.95,540,225)
print('Probability for the annual profit of 95% is',p1)
# Out:
# Probability for the annual profit of 95% is (99.00810347848784, 980.9918965215122)

# %% [markdown]
# # Qno-5(b)

# %%
# To compute 5th percentile, we use the formula X=X=μ+Zσ ; wherein from x table, 5 percentile=-1.645
x=540+(-1.645)*(225)
print('5th percentile of profit (in Million Rupees) is',np.round(x,))
# Out:
# 5th percentile of profit (in Million Rupees) is 170.0

# %% [markdown]
# # Qno-5(c)

# %%
#probability of division of 1 making a loss is
p1=stats.norm.cdf(0,5,3)
print('The probability of division of 1 making loss',np.round(p1,4))
# Out:
# The probability of division of 1 making loss 0.0478

# %%
#probability of division of 2 making a loss is
p2=stats.norm.cdf(0,7,4)
print('The probability of division of 2 making loss',np.round(p2,4))
# Out:
# The probability of division of 2 making loss 0.0401

# %% [markdown]
# # SET-3

# %% [markdown]
# # Qno-5

# %%
z=(0.046-0.05)/(np.sqrt((0.05*(1-0.05))/2000))
print('z-score is',np.round(z,4))
# Out:
# z-score is -0.8208

# %%
p=stats.norm.cdf(z)
p
# Out:
# 0.20588503245107104

# %% [markdown]
# # Qno-8

# %%
stats.norm.ppf(0.975)
# Out:
# 1.959963984540054

# %%
n=[(((1.9599)**2)*((0.5)**2))/((0.04)**2)]
n
# Out:
# [600.1887515625]

# %% [markdown]
# # Qno-9

# %%
stats.norm.ppf(0.99)
# Out:
# 2.3263478740408408

# %%
n=(((2.326)**2)*((0.5)**2))/((0.04)**2)
n
# Out:
# 845.355625

# %% [markdown]
# # Set-4

# %% [markdown]
# # Qno-3

# %%
#The description required for problem solving
#mean=50
#standard Deviation=40
#n=100
#degree of freedom=100-1=99

# %%
#probability that in a given week there can be investigated
#the mean transaction amount of the sample is between $45 and $55

# %%
c1=(45-50)/(40/np.sqrt(100))
c1
# Out:
# -1.25

# %%
c2=(55-50)/(40/np.sqrt(100))
c2
# Out:
# 1.25

# %%
prob=stats.norm.cdf(1.25)-stats.norm.cdf(-1.25)
prob
# Out:
# 0.7887004526662893

# %%
stats.norm.interval(0.7887,loc=50,scale=40/np.sqrt(100))
# Out:
# (45.00000495667348, 54.99999504332652)

# %%
print('The probability that in any given week there will be investigation',np.round((1-prob)*100,3),'%')
# Out:
# The probability that in any given week there will be investigation 21.13 %

# %% [markdown]
# # Qno-4

# %%
stats.norm.ppf(0.975)
# Out:
# 1.959963984540054

# %%
stats.norm.interval(0.99,100,20)
# Out:
# (48.48341392902199, 151.516586070978)

# %% [markdown]
# # completed
