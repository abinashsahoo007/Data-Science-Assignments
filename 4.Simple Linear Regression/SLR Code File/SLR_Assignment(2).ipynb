# %% [markdown]
# # **Simple Linear Regression(SLR) Assignment**

# %% [markdown]
# # ***Assignment 4(b)***

# %% [markdown]
# # ***2.Salary_Data dataset(Salary_Data.csv)***

# %% [markdown]
# # **Importing Libraries**

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.formula.api as smf
import statsmodels.api as sm
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Importing DataSet**

# %%
#importing DataSet
data=pd.read_csv('Salary_Data.csv')

# %%
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
data.shape
# Out:
# (30, 2)

# %%
#checking missing values
data.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
#checking duplicates
data.duplicated().sum()
# Out:
# 0

# %%
data.dtypes
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %% [markdown]
# # **Correlation**

# %%
data.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %% [markdown]
# # **Visualization**

# %% [markdown]
# # **Heatmap**

# %%
#heatmap
sns.heatmap(data.corr(),annot=True,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# # **Pairplot**

# %%
#pairplot
sns.pairplot(data)

# %% [markdown]
# # **Histogram**

# %%
#histogram
sns.histplot(data['Salary'])
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
sns.histplot(data['YearsExperience'])
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Count'>

# %% [markdown]
# # **Boxplot**

# %%
#box plot
sns.boxplot(data['Salary'])
# Out:
# <Axes: >

# %%
sns.boxplot(data['YearsExperience'])
# Out:
# <Axes: >

# %%
#box plot for two features
plt.subplots(figsize=(9,5))
plt.subplot(121)
plt.boxplot(data['Salary'])
plt.title('Salary')
plt.subplot(122)
plt.boxplot(data['YearsExperience'])
plt.title('YearsExperience')
plt.show()

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
#scatterplot
sns.scatterplot(x='YearsExperience',y='Salary',data=data)
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
#line plot
sns.lineplot(x='YearsExperience',y='Salary',data=data)
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
sns.scatterplot(x='YearsExperience',y='Salary',data=data,color='blue')
sns.lineplot(x='YearsExperience',y='Salary',data=data,color='red')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
#regression plot
sns.regplot(x='YearsExperience',y='Salary',data=data,color='green')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %% [markdown]
# # **Distplot**

# %%
#dist plot
sns.distplot(data['YearsExperience'])
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Density'>

# %%
sns.distplot(np.log(data['YearsExperience']))
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Density'>

# %%
sns.distplot(data['YearsExperience'],label='Before Transformation')
sns.distplot(np.log(data['YearsExperience']),color='red',label='After Transformation')
plt.show()

# %% [markdown]
# # ***qqplots***

# %%
#for YearsExperience

# %%
sm.qqplot(data['YearsExperience'],line='r',label='no transformation')
plt.legend()

# %%
sm.qqplot(np.log(data['YearsExperience']),line='r',label='log transformation')
plt.legend()

# %%
sm.qqplot(np.sqrt(data['YearsExperience']),line='r',label='sqrt transformation')
plt.legend()

# %%
sm.qqplot(np.cbrt(data['YearsExperience']),line='r',label='cube transformation')
plt.legend()

# %%
#for salary

# %%
sm.qqplot(data['Salary'],line='r',label='no transformation')
plt.legend()

# %%
sm.qqplot(np.log(data['Salary']),line='r',label='log transformation')
plt.legend()

# %%
sm.qqplot(np.sqrt(data['Salary']),line='r',label='sqrt transformation')
plt.legend()

# %%
sm.qqplot(np.cbrt(data['Salary']),line='r',label='cube transformation')
plt.legend()

# %% [markdown]
# # **Model Building**

# %% [markdown]
# # **Transformations**

# %%
#transformation

# %%
#dependent features is Salary
#independent feature is YearsExperience

# %% [markdown]
# # ***1.no transformation***

# %%
model=smf.ols('Salary~YearsExperience',data=data).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Sat, 13 Jan 2024   Prob (F-statistic):           1.14e-20
# Time:                        19:39:24   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
pred=model.predict(data['YearsExperience'])

# %%
pred
# Out:
# 0      36187.158752
# 1      38077.151217
# 2      39967.143681
# 3      44692.124842
# 4      46582.117306
# 5      53197.090931
# 6      54142.087163
# 7      56032.079627
# 8      56032.079627
# 9      60757.060788
# 10     62647.053252
# 11     63592.049484
# 12     63592.049484
# 13     64537.045717
# 14     68317.030645
# 15     72097.015574
# 16     73987.008038
# 17     75877.000502
# 18     81546.977895
# 19     82491.974127
# 20     90051.943985
# 21     92886.932681
# 22    100446.902538
# 23    103281.891235
# 24    108006.872395
# 25    110841.861092
# 26    115566.842252
# 27    116511.838485
# 28    123126.812110
# 29    125016.804574
# dtype: float64

# %%
model.resid
# Out:
# 0      3155.841248
# 1      8127.848783
# 2     -2236.143681
# 3     -1167.124842
# 4     -6691.117306
# 5      3444.909069
# 6      6007.912837
# 7     -1587.079627
# 8      8412.920373
# 9     -3568.060788
# 10      570.946748
# 11    -7798.049484
# 12    -6635.049484
# 13    -7456.045717
# 14    -7206.030645
# 15    -4159.015574
# 16    -7958.008038
# 17     7210.999498
# 18     -183.977895
# 19    11448.025873
# 20     1686.056015
# 21     5386.067319
# 22      855.097462
# 23    10530.108765
# 24     1424.127605
# 25    -5259.861092
# 26     1402.157748
# 27    -3876.838485
# 28     -735.812110
# 29    -3144.804574
# dtype: float64

# %%
data['Salary']
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
rmse=np.sqrt(np.mean((np.array(data['Salary'])-np.array(pred))**2))

# %%
rmse
# Out:
# 5592.043608760662

# %%
model.rsquared
# Out:
# 0.9569566641435086

# %%
#scatter plot
sns.scatterplot(x='YearsExperience',y='Salary',data=data,color='black')
sns.lineplot(x='YearsExperience',y=pred,data=data,color='red')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
#regression plot
sns.regplot(x='YearsExperience',y='Salary',data=data,color='black')
sns.regplot(x='YearsExperience',y=pred,data=data,color='red')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
#Accuracy is 0.9569566641435086 i.e 96%

# %% [markdown]
# # ***2.log transformation***

# %%
model2=smf.ols('Salary~np.log(YearsExperience)',data=data).fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.849
# Method:                 Least Squares   F-statistic:                     163.6
# Date:                Sat, 13 Jan 2024   Prob (F-statistic):           3.25e-13
# Time:                        19:39:25   Log-Likelihood:                -319.77
# No. Observations:                  30   AIC:                             643.5
# Df Residuals:                      28   BIC:                             646.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %%
pred2=model2.predict(data['YearsExperience'])

# %%
pred2
# Out:
# 0      18795.848339
# 1      25575.235192
# 2      31382.551905
# 3      43057.262306
# 4      46925.138875
# 5      58136.050079
# 6      59511.842441
# 7      62130.943929
# 8      62130.943929
# 9      68022.718504
# 10     70159.105863
# 11     71186.552842
# 12     71186.552842
# 13     72188.628149
# 14     75966.422577
# 15     79422.295729
# 16     81045.791737
# 17     82606.829882
# 18     86959.066704
# 19     87641.132977
# 20     92720.502137
# 21     94472.514696
# 22     98805.371390
# 23    100317.918684
# 24    102719.920751
# 25    104095.713112
# 26    106289.868435
# 27    106714.814600
# 28    109571.007247
# 29    110351.454145
# dtype: float64

# %%
model2.resid
# Out:
# 0     20547.151661
# 1     20629.764808
# 2      6348.448095
# 3       467.737694
# 4     -7034.138875
# 5     -1494.050079
# 6       638.157559
# 7     -7685.943929
# 8      2314.056071
# 9    -10833.718504
# 10    -6941.105863
# 11   -15392.552842
# 12   -14229.552842
# 13   -15107.628149
# 14   -14855.422577
# 15   -11484.295729
# 16   -15016.791737
# 17      481.170118
# 18    -5596.066704
# 19     6298.867023
# 20     -982.502137
# 21     3800.485304
# 22     2496.628610
# 23    13494.081316
# 24     6711.079249
# 25     1486.286888
# 26    10679.131565
# 27     5920.185400
# 28    12819.992753
# 29    11520.545855
# dtype: float64

# %%
data['Salary']
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
rmse2=np.sqrt(np.mean((np.array(data['Salary'])-np.array(pred2))**2))

# %%
rmse2
# Out:
# 10302.893706228306

# %%
model2.rsquared
# Out:
# 0.8538888828756969

# %%
#scatterplot
sns.scatterplot(x='YearsExperience',y='Salary',data=data,color='black')
sns.lineplot(x='YearsExperience',y=pred2,data=data,color='blue')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
#regressionplot
sns.regplot(x='YearsExperience',y='Salary',data=data,color='black')
sns.regplot(x='YearsExperience',y=pred2,data=data,color='blue')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
#Accuracy is 0.8538888828756969 i.e 85%

# %% [markdown]
# # ***3.exponential transformation***

# %%
model3=smf.ols('np.log(Salary)~YearsExperience',data=data).fit()

# %%
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         np.log(Salary)   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     383.6
# Date:                Sat, 13 Jan 2024   Prob (F-statistic):           7.03e-18
# Time:                        19:39:27   Log-Likelihood:                 28.183
# No. Observations:                  30   AIC:                            -52.37
# Df Residuals:                      28   BIC:                            -49.56
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
pred3=model3.predict(data['YearsExperience'])

# %%
pred3=np.exp(pred3)

# %%
pred3
# Out:
# 0      41998.957468
# 1      43066.066794
# 2      44160.289228
# 3      47019.029189
# 4      48213.688474
# 5      52639.142472
# 6      53303.675386
# 7      54658.014935
# 8      54658.014935
# 9      58196.330788
# 10     59674.982903
# 11     60428.338456
# 12     60428.338456
# 13     61191.204604
# 14     64340.199291
# 15     67651.246149
# 16     69370.128712
# 17     71132.684635
# 18     76693.630780
# 19     77661.835040
# 20     85860.704208
# 21     89153.725393
# 22     98565.809591
# 23    102346.110512
# 24    108971.540758
# 25    113150.933364
# 26    120475.819601
# 27    121996.743836
# 28    133194.621344
# 29    136578.829694
# dtype: float64

# %%
model3.resid
# Out:
# 0    -0.065327
# 1     0.070353
# 2    -0.157344
# 3    -0.077217
# 4    -0.189492
# 5     0.073291
# 6     0.120836
# 7    -0.003905
# 8     0.164716
# 9    -0.017461
# 10    0.057676
# 11   -0.079792
# 12   -0.059162
# 13   -0.069532
# 14   -0.051493
# 15    0.004230
# 16   -0.049362
# 17    0.155353
# 18    0.059102
# 19    0.190292
# 20    0.066210
# 21    0.097387
# 22    0.027382
# 23    0.106188
# 24    0.004207
# 25   -0.069235
# 26   -0.029540
# 27   -0.079842
# 28   -0.084591
# 29   -0.113931
# dtype: float64

# %%
data['Salary']
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
rmse3=np.sqrt(np.mean((np.array(data['Salary'])-np.array(pred3))**2))

# %%
rmse3
# Out:
# 7213.235076620168

# %%
model3.rsquared
# Out:
# 0.9319671194084196

# %%
#scatterplot
sns.scatterplot(x='YearsExperience',y='Salary',data=data,color='black')
sns.lineplot(x='YearsExperience',y=pred3,data=data,color='orange')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
#regressionplot
sns.regplot(x='YearsExperience',y='Salary',data=data,color='black')
sns.regplot(x='YearsExperience',y=pred3,data=data,color='orange')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
#Accuracy is 0.9319671194084196 is 93%

# %% [markdown]
# # ***4.sqrt transformation***

# %%
model4=smf.ols('Salary~np.sqrt(YearsExperience)',data=data).fit()

# %%
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.931
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                     377.8
# Date:                Sat, 13 Jan 2024   Prob (F-statistic):           8.57e-18
# Time:                        19:39:28   Log-Likelihood:                -308.52
# No. Observations:                  30   AIC:                             621.0
# Df Residuals:                      28   BIC:                             623.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
pred4=model4.predict(data['YearsExperience'])

# %%
pred4
# Out:
# 0      27470.511884
# 1      31262.287009
# 2      34771.976586
# 3      42635.056211
# 4      45499.687794
# 5      54617.343293
# 6      55825.518202
# 7      58182.905200
# 8      58182.905200
# 9      63772.383867
# 10     65901.508208
# 11     66945.592049
# 12     66945.592049
# 13     67976.704394
# 14     71980.468875
# 15     75809.903446
# 16     77665.963118
# 17     79485.972499
# 18     84749.033766
# 19     85599.722290
# 20     92164.765553
# 21     94526.218887
# 22    100589.939171
# 23    102784.094601
# 24    106353.652306
# 25    108446.272632
# 26    111857.919142
# 27    112529.386687
# 28    117134.909368
# 29    118421.805716
# dtype: float64

# %%
model4.resid
# Out:
# 0     11872.488116
# 1     14942.712991
# 2      2959.023414
# 3       889.943789
# 4     -5608.687794
# 5      2024.656707
# 6      4324.481798
# 7     -3737.905200
# 8      6262.094800
# 9     -6583.383867
# 10    -2683.508208
# 11   -11151.592049
# 12    -9988.592049
# 13   -10895.704394
# 14   -10869.468875
# 15    -7871.903446
# 16   -11636.963118
# 17     3602.027501
# 18    -3386.033766
# 19     8340.277710
# 20     -426.765553
# 21     3746.781113
# 22      712.060829
# 23    11027.905399
# 24     3077.347694
# 25    -2864.272632
# 26     5111.080858
# 27      105.613313
# 28     5256.090632
# 29     3450.194284
# dtype: float64

# %%
data['Salary']
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
rmse4=np.sqrt(np.mean((np.array(data['Salary'])-np.array(pred4))**2))

# %%
rmse4
# Out:
# 7080.09573498304

# %%
model4.rsquared
# Out:
# 0.9310009544993526

# %%
#scatterplot
sns.scatterplot(x='YearsExperience',y='Salary',data=data,color='black')
sns.lineplot(x='YearsExperience',y=pred4,data=data,color='green')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
#regressionplot
sns.regplot(x='YearsExperience',y='Salary',data=data,color='black')
sns.regplot(x='YearsExperience',y=pred4,data=data,color='green')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
#Accuracy is 0.9310009544993526 i.e 93%

# %% [markdown]
# # ***5.cube transformation***

# %%
model5=smf.ols('Salary~np.cbrt(YearsExperience)',data=data).fit()

# %%
model5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.911
# Model:                            OLS   Adj. R-squared:                  0.908
# Method:                 Least Squares   F-statistic:                     287.7
# Date:                Sat, 13 Jan 2024   Prob (F-statistic):           2.91e-16
# Time:                        19:39:30   Log-Likelihood:                -312.29
# No. Observations:                  30   AIC:                             628.6
# Df Residuals:                      28   BIC:                             631.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
pred5=model5.predict(data['YearsExperience'])

# %%
pred5
# Out:
# 0      24463.801275
# 1      29131.601199
# 2      33342.086479
# 3      42439.314513
# 4      45650.825046
# 5      55557.034160
# 6      56836.763462
# 7      59313.323958
# 8      59313.323958
# 9      65083.071599
# 10     67245.157746
# 11     68298.552558
# 12     68298.552558
# 13     69334.533886
# 14     73317.728330
# 15     77071.347199
# 16     78871.841921
# 17     80625.859192
# 18     85636.577536
# 19     86438.201554
# 20     92551.294556
# 21     94719.723555
# 22    100218.353827
# 23    102184.405588
# 24    105357.227078
# 25    107202.916114
# 26    110189.976243
# 27    110774.734426
# 28    114758.482804
# 29    115863.387681
# dtype: float64

# %%
model5.resid
# Out:
# 0     14879.198725
# 1     17073.398801
# 2      4388.913521
# 3      1085.685487
# 4     -5759.825046
# 5      1084.965840
# 6      3313.236538
# 7     -4868.323958
# 8      5131.676042
# 9     -7894.071599
# 10    -4027.157746
# 11   -12504.552558
# 12   -11341.552558
# 13   -12253.533886
# 14   -12206.728330
# 15    -9133.347199
# 16   -12842.841921
# 17     2462.140808
# 18    -4273.577536
# 19     7501.798446
# 20     -813.294556
# 21     3553.276445
# 22     1083.646173
# 23    11627.594412
# 24     4073.772922
# 25    -1620.916114
# 26     6779.023757
# 27     1860.265574
# 28     7632.517196
# 29     6008.612319
# dtype: float64

# %%
data['Salary']
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
rmse5=np.sqrt(np.mean((np.array(data['Salary'])-np.array(pred5))**2))

# %%
rmse5
# Out:
# 8027.035983458383

# %%
model5.rsquared
# Out:
# 0.9113098800320786

# %%
#scatterplot
sns.scatterplot(x='YearsExperience',y='Salary',data=data,color='black')
sns.lineplot(x='YearsExperience',y=pred5,data=data,color='brown')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
#regressionplot
sns.regplot(x='YearsExperience',y='Salary',data=data,color='black')
sns.regplot(x='YearsExperience',y=pred5,data=data,color='brown')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
#Accuracy is 0.9113098800320786 i.e 91%

# %%
print(model.rsquared)
print(model2.rsquared)
print(model3.rsquared)
print(model4.rsquared)
print(model5.rsquared)
# Out:
# 0.9569566641435086
# 0.8538888828756969
# 0.9319671194084196
# 0.9310009544993526
# 0.9113098800320786

# %%
print(rmse)
print(rmse2)
print(rmse3)
print(rmse4)
print(rmse5)
# Out:
# 5592.043608760662
# 10302.893706228306
# 7213.235076620168
# 7080.09573498304
# 8027.035983458383

# %%
# from above 'model' has good rsquare value so the accuracy is high we will consider 'model' for futher operation
# model is formed without using any transformation i.e no transformation

# %% [markdown]
# **from above 'model' [i.e with no transformation] has good rsquare value, so the accuracy is high, so we will consider 'model' for futher operation**
#
# **rsquared=0.95(i.e 95%) more than 85%,**
# **Very good accuracy**

# %% [markdown]
# # **Conclusion**

# %%
#So for above models good accuracy and rsquare with least error we got is 'model' with, rsquared=0.95(i.e 95%)

# %%
#residuals

# %%
sns.histplot(model.resid_pearson)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.scatterplot(model.resid_pearson)
sns.lineplot(model.resid_pearson)
# Out:
# <Axes: >

# %%
sm.qqplot(model.resid,line='q')
plt.show()

# %% [markdown]
# # **Prediction**

# %%
#Adding predicted values to Data Frame

# %%
data['Prediction_hike Salary']=pred

# %%
data
# Out:
#     YearsExperience    Salary  Prediction_hike Salary
# 0               1.1   39343.0            36187.158752
# 1               1.3   46205.0            38077.151217
# 2               1.5   37731.0            39967.143681
# 3               2.0   43525.0            44692.124842
# 4               2.2   39891.0            46582.117306
# 5               2.9   56642.0            53197.090931
# 6               3.0   60150.0            54142.087163
# 7               3.2   54445.0            56032.079627
# 8               3.2   64445.0            56032.079627
# 9               3.7   57189.0            60757.060788
# 10              3.9   63218.0            62647.053252
# 11              4.0   55794.0            63592.049484
# 12              4.0   56957.0            63592.049484
# 13              4.1   57081.0            64537.045717
# 14              4.5   61111.0            68317.030645
# 15              4.9   67938.0            72097.015574
# ...

# %%
#completed

# %% [markdown]
# # **Completed**
